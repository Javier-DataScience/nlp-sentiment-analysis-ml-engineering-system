# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

# %%
# Load data

import pandas as pd

train_df = pd.read_csv("../data/raw/train.csv")
test_df = pd.read_csv("../data/raw/test.csv")

train_df.head()
# Out:
#                           text  label
# 0            I love this movie      1
# 1  Terrible movie, very boring      0
# 2     Amazing story and acting      1
# 3          I really enjoyed it      1
# 4             I hate this film      0

# %%
train_df["label"].value_counts()
# Out:
# label
# 1    3
# 0    3
# Name: count, dtype: int64

# %%
for i in range(len(train_df)):
    print(train_df["text"].iloc[i])
# Out:
# I love this movie
# Terrible movie, very boring
# Amazing story and acting
# I really enjoyed it
# I hate this film
# Not good at all

# %%
from src.features.tokenizer import SimpleTokenizer

tokenizer = SimpleTokenizer()

sample = train_df["text"].iloc[0]
tokenizer.tokenize(sample)
# Out:
# ['i', 'love', 'this', 'movie']
